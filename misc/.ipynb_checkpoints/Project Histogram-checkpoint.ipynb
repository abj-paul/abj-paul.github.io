# %%
import matplotlib.pyplot as plt

# Sample data
projects = {
    "Computer Vision": 3,
    "Etherium/Solana Contract": 7,
    "Web Design": 10,
    "NLP": 15
}

# Plotting the horizontal histogram
plt.barh(range(len(data)), data)

# Adding labels and title
plt.xlabel('Y-axis')
plt.ylabel('X-axis')
plt.title('Horizontal Histogram')

# Adding labels for each bar
for i in range(len(data)):
    plt.text(data[i], i, str(data[i]), ha='left', va='center')
    plt.annotate(str(data[i]), xy=(data[i], i), xytext=(data[i] + 1, i), ha='left', va='center')

plt.show()
